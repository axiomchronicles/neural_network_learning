# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

import pathlib

# %%
RootDir: pathlib.Path = pathlib.Path("../datasets")
ResumeFile = RootDir / "Resume.csv"

# %%
df = pd.read_csv(ResumeFile)
