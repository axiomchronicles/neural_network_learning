# %%
import torch
import torchvision
import pandas as pd
import matplotlib.pyplot as plt
import pathlib

from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader

# %%
root = pathlib.Path(pathlib.Path.home() / "Downloads" / "csiro-biomass")

# %%
train_data = pd.read_csv(root / "train.csv")

# %%
train_data.head()
# Out:
#                     sample_id              image_path Sampling_Date State  \
# 0  ID1011485656__Dry_Clover_g  train/ID1011485656.jpg      2015/9/4   Tas
# 1    ID1011485656__Dry_Dead_g  train/ID1011485656.jpg      2015/9/4   Tas
# 2   ID1011485656__Dry_Green_g  train/ID1011485656.jpg      2015/9/4   Tas
# 3   ID1011485656__Dry_Total_g  train/ID1011485656.jpg      2015/9/4   Tas
# 4         ID1011485656__GDM_g  train/ID1011485656.jpg      2015/9/4   Tas
#
#            Species  Pre_GSHH_NDVI  Height_Ave_cm   target_name   target
# 0  Ryegrass_Clover           0.62         4.6667  Dry_Clover_g   0.0000
# 1  Ryegrass_Clover           0.62         4.6667    Dry_Dead_g  31.9984
# 2  Ryegrass_Clover           0.62         4.6667   Dry_Green_g  16.2751
# 3  Ryegrass_Clover           0.62         4.6667   Dry_Total_g  48.2735
# 4  Ryegrass_Clover           0.62         4.6667         GDM_g  16.2750

# %%
sampling_date = pd.to_datetime(train_data["Sampling_Date"])

# %%
train_data["Sampling_Year"] = sampling_date.dt.year
train_data["Sampling_Month"] = sampling_date.dt.month
train_data["Sampling_Day"] = sampling_date.dt.day

# %%
train_data
# Out:
#                        sample_id              image_path Sampling_Date State  \
# 0     ID1011485656__Dry_Clover_g  train/ID1011485656.jpg      2015/9/4   Tas
# 1       ID1011485656__Dry_Dead_g  train/ID1011485656.jpg      2015/9/4   Tas
# 2      ID1011485656__Dry_Green_g  train/ID1011485656.jpg      2015/9/4   Tas
# 3      ID1011485656__Dry_Total_g  train/ID1011485656.jpg      2015/9/4   Tas
# 4            ID1011485656__GDM_g  train/ID1011485656.jpg      2015/9/4   Tas
# ...                          ...                     ...           ...   ...
# 1780   ID983582017__Dry_Clover_g   train/ID983582017.jpg      2015/9/1    WA
# 1781     ID983582017__Dry_Dead_g   train/ID983582017.jpg      2015/9/1    WA
# 1782    ID983582017__Dry_Green_g   train/ID983582017.jpg      2015/9/1    WA
# 1783    ID983582017__Dry_Total_g   train/ID983582017.jpg      2015/9/1    WA
# 1784          ID983582017__GDM_g   train/ID983582017.jpg      2015/9/1    WA
#
#               Species  Pre_GSHH_NDVI  Height_Ave_cm   target_name   target  \
# 0     Ryegrass_Clover           0.62         4.6667  Dry_Clover_g   0.0000
# 1     Ryegrass_Clover           0.62         4.6667    Dry_Dead_g  31.9984
# 2     Ryegrass_Clover           0.62         4.6667   Dry_Green_g  16.2751
# 3     Ryegrass_Clover           0.62         4.6667   Dry_Total_g  48.2735
# 4     Ryegrass_Clover           0.62         4.6667         GDM_g  16.2750
# ...               ...            ...            ...           ...      ...
# 1780         Ryegrass           0.64         9.0000  Dry_Clover_g   0.0000
# 1781         Ryegrass           0.64         9.0000    Dry_Dead_g   0.0000
# 1782         Ryegrass           0.64         9.0000   Dry_Green_g  40.9400
# 1783         Ryegrass           0.64         9.0000   Dry_Total_g  40.9400
# 1784         Ryegrass           0.64         9.0000         GDM_g  40.9400
#
#       Sampling_Year  Sampling_Month  Sampling_Day
# 0              2015               9             4
# 1              2015               9             4
# 2              2015               9             4
# 3              2015               9             4
# 4              2015               9             4
# ...             ...             ...           ...
# 1780           2015               9             1
# 1781           2015               9             1
# 1782           2015               9             1
# 1783           2015               9             1
# 1784           2015               9             1
#
# [1785 rows x 12 columns]

# %%
state_encoder = LabelEncoder()
species_encoder = LabelEncoder()

# %%
train_data["State_encoded"] = state_encoder.fit_transform(train_data["State"])
train_data["Species_encoded"] = species_encoder.fit_transform(train_data["Species"])

# %%
train_data.head()
# Out:
#                     sample_id              image_path Sampling_Date State  \
# 0  ID1011485656__Dry_Clover_g  train/ID1011485656.jpg      2015/9/4   Tas
# 1    ID1011485656__Dry_Dead_g  train/ID1011485656.jpg      2015/9/4   Tas
# 2   ID1011485656__Dry_Green_g  train/ID1011485656.jpg      2015/9/4   Tas
# 3   ID1011485656__Dry_Total_g  train/ID1011485656.jpg      2015/9/4   Tas
# 4         ID1011485656__GDM_g  train/ID1011485656.jpg      2015/9/4   Tas
#
#            Species  Pre_GSHH_NDVI  Height_Ave_cm   target_name   target  \
# 0  Ryegrass_Clover           0.62         4.6667  Dry_Clover_g   0.0000
# 1  Ryegrass_Clover           0.62         4.6667    Dry_Dead_g  31.9984
# 2  Ryegrass_Clover           0.62         4.6667   Dry_Green_g  16.2751
# 3  Ryegrass_Clover           0.62         4.6667   Dry_Total_g  48.2735
# 4  Ryegrass_Clover           0.62         4.6667         GDM_g  16.2750
#
#    Sampling_Year  Sampling_Month  Sampling_Day  State_encoded  Species_encoded
# 0           2015               9             4              1               11
# 1           2015               9             4              1               11
# 2           2015               9             4              1               11
# 3           2015               9             4              1               11
# 4           2015               9             4              1               11

# %%
train_data["NDVI_height"] = train_data["Pre_GSHH_NDVI"] ** train_data["Height_Ave_cm"]
train_data["NDVI_sq"] = train_data["Pre_GSHH_NDVI"] ** 2
train_data["Height_sq"] = train_data["Height_Ave_cm"] ** 2

# %%
train_data.head()
# Out:
#                     sample_id              image_path Sampling_Date State  \
# 0  ID1011485656__Dry_Clover_g  train/ID1011485656.jpg      2015/9/4   Tas
# 1    ID1011485656__Dry_Dead_g  train/ID1011485656.jpg      2015/9/4   Tas
# 2   ID1011485656__Dry_Green_g  train/ID1011485656.jpg      2015/9/4   Tas
# 3   ID1011485656__Dry_Total_g  train/ID1011485656.jpg      2015/9/4   Tas
# 4         ID1011485656__GDM_g  train/ID1011485656.jpg      2015/9/4   Tas
#
#            Species  Pre_GSHH_NDVI  Height_Ave_cm   target_name   target  \
# 0  Ryegrass_Clover           0.62         4.6667  Dry_Clover_g   0.0000
# 1  Ryegrass_Clover           0.62         4.6667    Dry_Dead_g  31.9984
# 2  Ryegrass_Clover           0.62         4.6667   Dry_Green_g  16.2751
# 3  Ryegrass_Clover           0.62         4.6667   Dry_Total_g  48.2735
# 4  Ryegrass_Clover           0.62         4.6667         GDM_g  16.2750
#
#    Sampling_Year  Sampling_Month  Sampling_Day  State_encoded  \
# 0           2015               9             4              1
# 1           2015               9             4              1
# 2           2015               9             4              1
# 3           2015               9             4              1
# 4           2015               9             4              1
#
#    Species_encoded  NDVI_height  NDVI_sq  Height_sq
# 0               11     0.107437   0.3844  21.778089
# 1               11     0.107437   0.3844  21.778089
# 2               11     0.107437   0.3844  21.778089
# 3               11     0.107437   0.3844  21.778089
# 4               11     0.107437   0.3844  21.778089

# %%
train_data["mean_target_per_species"] = train_data.groupby("Species")["target"].transform("mean")
train_data["mean_target_per_state"] = train_data.groupby("State")["target"].transform("mean")

# %%
train_data.head()
# Out:
#                     sample_id              image_path Sampling_Date State  \
# 0  ID1011485656__Dry_Clover_g  train/ID1011485656.jpg      2015/9/4   Tas
# 1    ID1011485656__Dry_Dead_g  train/ID1011485656.jpg      2015/9/4   Tas
# 2   ID1011485656__Dry_Green_g  train/ID1011485656.jpg      2015/9/4   Tas
# 3   ID1011485656__Dry_Total_g  train/ID1011485656.jpg      2015/9/4   Tas
# 4         ID1011485656__GDM_g  train/ID1011485656.jpg      2015/9/4   Tas
#
#            Species  Pre_GSHH_NDVI  Height_Ave_cm   target_name   target  \
# 0  Ryegrass_Clover           0.62         4.6667  Dry_Clover_g   0.0000
# 1  Ryegrass_Clover           0.62         4.6667    Dry_Dead_g  31.9984
# 2  Ryegrass_Clover           0.62         4.6667   Dry_Green_g  16.2751
# 3  Ryegrass_Clover           0.62         4.6667   Dry_Total_g  48.2735
# 4  Ryegrass_Clover           0.62         4.6667         GDM_g  16.2750
#
#    Sampling_Year  Sampling_Month  Sampling_Day  State_encoded  \
# 0           2015               9             4              1
# 1           2015               9             4              1
# 2           2015               9             4              1
# 3           2015               9             4              1
# 4           2015               9             4              1
#
#    Species_encoded  NDVI_height  NDVI_sq  Height_sq  mean_target_per_species  \
# 0               11     0.107437   0.3844  21.778089                20.753122
# 1               11     0.107437   0.3844  21.778089                20.753122
# 2               11     0.107437   0.3844  21.778089                20.753122
# 3               11     0.107437   0.3844  21.778089                20.753122
# 4               11     0.107437   0.3844  21.778089                20.753122
#
#    mean_target_per_state
# 0              19.032785
# 1              19.032785
# 2              19.032785
# 3              19.032785
# 4              19.032785

# %%
import torch
from torch.utils.data import Dataset
import pandas as pd
from PIL import Image
import pathlib

class BiomassDataset(Dataset):
    def __init__(self, csv_path, root, transform=None, include_tabular=True):
        super().__init__()

        self.annotation = pd.read_csv(csv_path)
        self.root = pathlib.Path(root)
        self.transform = transform
        self.include_tabular = include_tabular

        self.grouped = (
            self.annotation
            .pivot_table(index=[
                "image_path", "Sampling_Date", "State", "Species",
                "Pre_GSHH_NDVI", "Height_Ave_cm"
            ], columns="target_name", values="target")
            .reset_index()
        )

        self.target_cols = [
            "Dry_Clover_g",
            "Dry_Dead_g",
            "Dry_Green_g",
            "Dry_Total_g",
            "GDM_g"
        ]

        if self.include_tabular:
            self._prepare_tabular_features()

    def _prepare_tabular_features(self):
        """Create engineered numeric tabular features."""

        df = self.grouped

        df["Sampling_Date"] = pd.to_datetime(df["Sampling_Date"], errors="coerce")
        df["month"] = df["Sampling_Date"].dt.month.fillna(0)
        df["dayofyear"] = df["Sampling_Date"].dt.dayofyear.fillna(0)

        df["State_enc"] = df["State"].astype("category").cat.codes
        df["Species_enc"] = df["Species"].astype("category").cat.codes

        df["NDVI_height"] = df["Pre_GSHH_NDVI"] * df["Height_Ave_cm"]
        df["NDVI_sq"] = df["Pre_GSHH_NDVI"] ** 2
        df["height_sq"] = df["Height_Ave_cm"] ** 2

        self.tabular_cols = [
            "Pre_GSHH_NDVI", "Height_Ave_cm", "month", "dayofyear",
            "State_enc", "Species_enc", "NDVI_height", "NDVI_sq", "height_sq"
        ]

        self.grouped = df

    def __len__(self):
        return len(self.grouped)

    def __getitem__(self, idx):
        row = self.grouped.iloc[idx]

        img_path = self.root / row["image_path"]
        image = Image.open(img_path).convert("RGB")
        if self.transform:
            image = self.transform(image)
            
        target = pd.to_numeric(row[self.target_cols], errors="coerce").astype("float32")
        target = torch.tensor(target.values, dtype=torch.float32)

        if self.include_tabular:
            tabular_data = pd.to_numeric(row[self.target_cols], errors = "coerce").astype("float32")
            tabular_data = torch.tensor(tabular_data.values, dtype=torch.float32)
            target = torch.cat([target, tabular_data])
            return image, target
        else:
            return image, target

# %%
class BiomassTestDataset(Dataset):
    def __init__(self, csv_path, root, transform = None):
        super(BiomassTestDataset, self).__init__()

        self.annonation = pd.read_csv(csv_path)
        self.root = pathlib.Path(root)
        self.transform = transform

    def __len__(self):
        return len(self.annonation)

    def __getitem__(self, idx):
        rows = self.annonation.iloc[idx]
        
        img_path = self.root / rows["image_path"]
        image = Image.open(img_path).convert("RGB")

        # target = pd.to_numeric(rows["target_name"], errors = "coerce").astype("float32")
        # target = torch.tensor(target).type(torch.float32)

        target = rows["target_name"]
        sample_id = rows["sample_id"]

        # target = torch.tensor(rows["target_name"], dtype=torch.float32)

        if self.transform:
            image = self.transform(image)

        return image, target, sample_id

# %%
from torchvision import transforms

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(25),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.1),
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
    transforms.ToTensor(),
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# %%
train_dataset = BiomassDataset(csv_path = root / "train.csv", root = root, transform = train_transform)
test_dataset = BiomassTestDataset(csv_path = root / "test.csv", root = root, transform = test_transform)

# %%
train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

image, tabular_data = next(iter(train_loader))
image.shape, target.shape
# Out:
# (torch.Size([32, 3, 224, 224]), torch.Size([32, 5]))

# %%
import torch
import torch.nn as nn
import torchvision

class CsiroHybridModel(nn.Module):
    def __init__(self, num_tabular_features: int = 14, hidden_units: int = 64, out_features: int = 5):
        super().__init__()

        self.cnn = torchvision.models.resnet18(weights=torchvision.models.ResNet18_Weights.IMAGENET1K_V1)
        in_features = self.cnn.fc.in_features
        self.cnn.fc = nn.Identity() 

        # self.tabular = nn.Sequential(
        #     nn.Linear(num_tabular_features, hidden_units),
        #     nn.BatchNorm1d(hidden_units),
        #     nn.ReLU(),
        #     nn.Dropout(0.25),
        #     nn.Linear(hidden_units, 32),
        #     nn.ReLU()
        # )

        self.fc = nn.Sequential(
            nn.Linear(in_features + 32, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, out_features)
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.cnn(x)         # [B, 512]
        print(x.shape)
        # x = self.tabular(x) # [B, 32]
        # print(x.shape)
        return self.fc(x)

# %%
device = "mps" if torch.mps.is_available() else "cpu"
torch.manual_seed(42)

# %%
model = CsiroHybridModel().to(device)
# model

# %%
def r2_score_fn(y_true, y_pred):
    ss_res = torch.sum((y_true - y_pred) ** 2, dim=0)
    ss_tot = torch.sum((y_true - torch.mean(y_true, dim=0)) ** 2, dim=0)
    r2 = 1 - ss_res / ss_tot
    return r2

def weighted_r2(y_true, y_pred):
    weights = torch.tensor([0.1, 0.1, 0.1, 0.5, 0.2], device=y_true.device)
    r2 = r2_score_fn(y_true, y_pred)
    final = torch.sum(weights * r2)
    return r2, final

# %%
def train_model(model, criterion, optimizer, scheduler, device, dataset, r2score):
    model.train()
    r2score.reset()
    total_loss = 0.0

    for img, target in dataset:
        img, target = img.to(device), target.to(device)

        optimizer.zero_grad()
        pred = model(img)
        loss = criterion(pred, target)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=2.0)
        optimizer.step()

        total_loss += loss.item()
        r2score.update(pred, target)

    if scheduler:
        scheduler.step()

    avg_loss = total_loss / len(dataset)
    avg_r2 = r2score.compute().item()
    return avg_loss, avg_r2

# %%
def eval_model(model, criterion, dataset, device):
    model.eval()
    total_loss = 0.0
    y_true, y_pred = [], []

    with torch.inference_mode():
        for img, target in dataset:
            img, target = img.to(device), target.to(device)
            pred = model(img)
            loss = criterion(pred, target)
            total_loss += loss.item()

            y_true.append(target)
            y_pred.append(pred)

    y_true = torch.cat(y_true)
    y_pred = torch.cat(y_pred)

    r2, weighted = weighted_r2(y_true, y_pred)
    return total_loss / len(dataset), r2.cpu(), weighted.cpu().item()

# %%
from torchmetrics.regression import R2Score
from tqdm.auto import tqdm

criterion = torch.nn.SmoothL1Loss() 
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)

r2score = R2Score().to(device)

# %%
best_r2 = -float("inf")
patience, trigger = 5, 0  

for epoch in tqdm(range(50), desc="Training"):
    train_loss, train_r2 = train_model(model, criterion, optimizer, scheduler, device, train_loader, r2score)
    val_loss, val_r2s, val_weighted_r2 = eval_model(model, criterion, val_loader, device)

    if epoch % (0.1 * 50) == 0:
        print(f"[Epoch {epoch+1}] Train Loss: {train_loss:.4f}, R²: {train_r2:.4f} | Val Loss: {val_loss:.4f}, Weighted R²: {val_weighted_r2:.4f}")
    
        if val_weighted_r2 > best_r2:
            best_r2 = val_weighted_r2
            torch.save(model.state_dict(), "best_model.pth")
            print("✅ Saved new best model")
# Out:
# Training:   0%|                                          | 0/50 [00:00<?, ?it/s]
# torch.Size([32, 512])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[156], line 5
#       2 patience, trigger = 5, 0
#       4 for epoch in tqdm(range(50), desc="Training"):
# ----> 5     train_loss, train_r2 = train_model(model, criterion, optimizer, scheduler, device, train_loader, r2score)
#       6     val_loss, val_r2s, val_weighted_r2 = eval_model(model, criterion, val_loader, device)
#       8     if epoch % (0.1 * 50) == 0:
#
# Cell In[153], line 10, in train_model(model, criterion, optimizer, scheduler, device, dataset, r2score)
#       7 img, target = img.to(device), target.to(device)
#       9 optimizer.zero_grad()
# ---> 10 pred = model(img)
#      11 loss = criterion(pred, target)
#      12 loss.backward()
#
# File ~/Desktop/NeuralNetworks/MachineLearning/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/NeuralNetworks/MachineLearning/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# Cell In[149], line 34, in CsiroHybridModel.forward(self, x)
#      31 print(x.shape)
#      32 # x = self.tabular(x) # [B, 32]
#      33 # print(x.shape)
# ---> 34 return self.fc(x)
#
# File ~/Desktop/NeuralNetworks/MachineLearning/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/NeuralNetworks/MachineLearning/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Desktop/NeuralNetworks/MachineLearning/.venv/lib/python3.13/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     246 """
#     247 Runs the forward pass.
#     248 """
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File ~/Desktop/NeuralNetworks/MachineLearning/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/NeuralNetworks/MachineLearning/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Desktop/NeuralNetworks/MachineLearning/.venv/lib/python3.13/site-packages/torch/nn/modules/linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: linear(): input and weight.T shapes cannot be multiplied (32x512 and 544x256)
